# %%
import cv2 
from matplotlib import pyplot as plt
import numpy as np
import Preprocess
import DetectPlates

# %%
img = cv2.imread('image/image4.jpg')
imgGrayscale, imgThresh = Preprocess.preprocess(img)
plt.imshow(cv2.cvtColor(imgGrayscale, cv2.COLOR_BGR2RGB))

# %%
listOfPossibleChars = DetectPlates.findPossibleCharsInScene(imgThresh)
# Out:
# step 2 - len(contours) = 3049
# step 2 - intCountOfPossibleChars = 73
# ...
